# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("./train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass          object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
def class_name(pclass):
    if pclass == 1:
        return "Upper"
    elif pclass == 2:
        return "Middle"
    elif pclass == 3:
        return "Lower"
    else:
        return pclass
data['Pclass'] = data['Pclass'].apply(class_name)

# %%
class_count = data['Pclass'].value_counts()
class_count.plot(kind="barh", figsize=(5, 1), title="Passenger Count by Class").set_xlabel("# Passengers")
# Out:
# Text(0.5,0,'# Passengers')

# %%
gender_count = data[['Sex', 'Survived']]
gender_count.groupby(by =['Sex', 'Survived']).count()
# gender_count.plot(kind="barh", figsize=(5, 1), title="Passenger Count by Class").set_xlabel("# Passengers")
# Out:
# Empty DataFrame
# Columns: []
# Index: [(female, 0), (female, 1), (male, 0), (male, 1)]

# %%
gender_survival = gender_count.groupby(['Sex', 'Survived']).size()

# %%
gender_count.groupby(['Sex', 'Survived'])

# %%
gender_count.groupby(['Sex', 'Survived']).size().plot(kind = 'bar', stacked = 'True')

# %%
tips = sns.load_dataset("tips")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(10,2), dpi = 200)
sns.scatterplot(data=data, y="Survived", x="Fare", hue="Sex", style = 'Pclass', legend = 'full')
plt.legend(loc= 'center right', fancybox=True,bbox_to_anchor=(1.2, 1.05))

# %%
data_filter = data[data.Fare <=80]
data_filter = data_filter[data.Sex == 'male']
plt.figure(figsize=(10,2), dpi = 200)
sns.scatterplot(data=data_filter, y="Survived", x="Fare", style = 'Pclass', legend = 'full')
plt.legend(loc= 'center right', fancybox=True,bbox_to_anchor=(1.2, 1.05))
# Out:
# /Users/veettily/opt/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0  Lower
# 1            2         1  Upper
# 2            3         1  Lower
# 3            4         1  Upper
# 4            5         0  Lower
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
